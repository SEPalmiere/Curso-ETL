# %%
import pandas as pd

# %%
import pandera as pa # pandera é uma biblioteca utilizada para validar dados do tipo data em um arquivo

# %%
# CARREGAMENTO DE DADOS

# %%
df = pd.read_csv("H://Meu_Github//Curso ETJ//ocorrencia_2010_2020.csv")

# %%
df
# Out:
#      codigo_ocorrencia;codigo_ocorrencia2;ocorrencia_classificacao;ocorrencia_cidade;ocorrencia_uf;ocorrencia_aerodromo;ocorrencia_dia;ocorrencia_hora;total_recomendacoes
# 0     40211;40211;INCIDENTE;RIO DE JANEIRO;RJ;****;0...
# 1     40349;40349;INCIDENTE;BELÉM;PA;SBBE;03/01/2010...
# 2     40351;40351;INCIDENTE;RIO DE JANEIRO;RJ;SBRJ;0...
# 3     39527;39527;ACIDENTE;LUCAS DO RIO VERDE;MT;***...
# 4     40324;40324;INCIDENTE;PELOTAS;RS;SBPK;05/01/20...
# ...                                                 ...
# 5747  79804;79804;INCIDENTE;CAMPINAS;SP;SBKP;29/12/2...
# 5748  79757;79757;INCIDENTE GRAVE;LAGOA DA CONFUSÃO;...
# 5749  79802;79802;INCIDENTE;RIO DE JANEIRO;RJ;SBGL;3...
# 5750  79756;79756;INCIDENTE GRAVE;VICENTINA;MS;****;...
# 5751  79844;79844;INCIDENTE;RIO DE JANEIRO;RJ;SBJR;3...
#
# [5752 rows x 1 columns]

# %%
df = pd.read_csv("H://Meu_Github//Curso ETJ//ocorrencia_2010_2020.csv",sep=";") # A inserção do sep (separador) indica que as divisoes são por ; e não por ,

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Visualização dos tipos de dados do dataframe

# %%
df.dtypes
# Out:
# codigo_ocorrencia            int64
# codigo_ocorrencia2           int64
# ocorrencia_classificacao    object
# ocorrencia_cidade           object
# ocorrencia_uf               object
# ocorrencia_aerodromo        object
# ocorrencia_dia              object
# ocorrencia_hora             object
# total_recomendacoes          int64
# dtype: object

# %%
# Correção da coluna de data

# %%
df = pd.read_csv("H://Meu_Github//Curso ETJ//ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'])

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
# Acessar o mês de uma data

# %%
df.ocorrencia_dia.dt.month
# Out:
# 0        3
# 1        3
# 2        3
# 3        4
# 4        5
#         ..
# 5747    12
# 5748    12
# 5749    12
# 5750    12
# 5751    12
# Name: ocorrencia_dia, Length: 5752, dtype: int64

# %%
# Corrigindo a coulna ocorrencia_dia para mostrar dia/mes/ano como no arquivo csv original

# %%
df = pd.read_csv("H://Meu_Github//Curso ETJ//ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst = True)

# %%
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Nan representa dados vazios em uma celula de texto e Nat representa dadoz vazios em uma célula de data

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %% [raw]
# Utilizando a biblioteca panderas para validar dataframe

# %%
schema = pa.DataFrameSchema(
columns = {
    "codigo_ocorrencia": pa.Column(pa.Int),
    "codigo_ocorrencia2": pa.Column(pa.Int),
    "ocorrencia_classificacao": pa.Column(pa.String),
    "ocorrencia_cidade": pa.Column(pa.String),
    "ocorrencia_uf": pa.Column(pa.String),
    "ocorrencia_aerodromo": pa.Column(pa.String),
    "ocorrencia_dia": pa.Column(pa.DateTime),
    "ocorrencia_hora": pa.Column(pa.String, nullable = True),
    "total_recomendacoes": pa.Column(pa.Int)
}
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Verificção se o horario de 0-24 é confiavel para a coluna ocorrencia_hora

# %%
schema = pa.DataFrameSchema(
columns = {
    "codigo_ocorrencia": pa.Column(pa.Int),
    "codigo_ocorrencia2": pa.Column(pa.Int),
    "ocorrencia_classificacao": pa.Column(pa.String),
    "ocorrencia_cidade": pa.Column(pa.String),
    "ocorrencia_uf": pa.Column(pa.String),
    "ocorrencia_aerodromo": pa.Column(pa.String),
    "ocorrencia_dia": pa.Column(pa.DateTime),
    "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable = True),
    "total_recomendacoes": pa.Column(pa.Int)
}
)

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Verificando se a sigla dos Estados possui reakmente apenas 2 caracteres

# %%
schema = pa.DataFrameSchema(
columns = {
    "codigo_ocorrencia": pa.Column(pa.Int),
    "codigo_ocorrencia2": pa.Column(pa.Int),
    "ocorrencia_classificacao": pa.Column(pa.String),
    "ocorrencia_cidade": pa.Column(pa.String),
    "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2)),
    "ocorrencia_aerodromo": pa.Column(pa.String),
    "ocorrencia_dia": pa.Column(pa.DateTime),
    "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable = True),
    "total_recomendacoes": pa.Column(pa.Int)
}
)

# %%
schema.validate(df)
# quando o schema validade da um erro como abaixo, ele indica que um dos tipos de valores necessarios para uma respectiva coluna não foi encontrado ou está diferente
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# <ipython-input-28-dc85ea979a2b> in <module>
# ----> 1 schema.validate(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     592                 check_results.append(isinstance(result, pd.DataFrame))
#     593             except errors.SchemaError as err:
# --> 594                 error_handler.collect_error("schema_component_check", err)
#     595             except errors.SchemaErrors as err:
#     596                 for schema_error_dict in err.schema_errors:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
# ...

# %%
# LIMPEZA DE DADOS

# %%
# Extrair dado de uma célula

# %%
df.loc[1,'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
# Extraindo dados de linhas especificas

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 40              39158               39158                INCIDENTE
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10  SÃO PEDRO DO SUL            RS                 ****     2010-01-10
# 40             BELÉM            PA                 ****     2010-01-28
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 40        16:00:00                    0

# %%
# Extrair coluna do dataframe

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
# Verificar se codigo_ocorrencia possui valores únicos para linhas diferentes

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
# Transformando codigo_ocorrencia em INDEX

# %%
df.set_index('codigo_ocorrencia', inplace = True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 ****
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 ****
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# ...

# %%
# Resetar Index e voltar ao Index original Cuidado pois ele deletar a coluna usada como index no caso codigo_ocorrencia

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
# Inserir nova coluna

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                    0                RJ
# 1                    0                PA
# ...

# %%
# Corrigir dados de uma celula

# %%
df.loc[0, 'ocorrencia_uf_bkp'] = 'SP'

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                    0                SP
# 1                    0                PA
# ...

# %%
df.loc[:, 'ocorrencia_uf_bkp'] = 'SP'

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 ****     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 ****     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes ocorrencia_uf_bkp
# 0                    0                SP
# 1                    0                SP
# ...

# %%
# Deletar coluna

# %%
df.drop(['ocorrencia_uf_bkp'], axis = 1, inplace = True)

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BELÉM
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                INCIDENTE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
# Alterar dado conforme valor passado como atributo

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 11                 40069                    GRAVE         SÃO PAULO
# 16                 39809                    GRAVE         SÃO PAULO
# 18                 39828                    GRAVE            SANTOS
# 26                 39847                    GRAVE          SOROCABA
# 27                 39768                    GRAVE          CAMPINAS
# ...                  ...                      ...               ...
# 5704               79739                    GRAVE         SÃO PAULO
# 5705               79705                    GRAVE          SOROCABA
# 5715               79718                    GRAVE         SÃO PAULO
# 5742               79800                    GRAVE         SÃO PAULO
# 5747               79804                    GRAVE          CAMPINAS
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 11              SP                 SBMT     2010-01-10        14:50:00
# ...

# %%
# Corrigindo o Dataframe Substituindo os **** por valores não informados NA

# %%
# NA not available usado para dados não numerico Nan usado para dados numericos porem precisa da biblioteca numpy e NT not a type

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0               40211                INCIDENTE      RIO DE JANEIRO
# 1               40349                INCIDENTE               BELÉM
# 2               40351                INCIDENTE      RIO DE JANEIRO
# 3               39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4               40324                INCIDENTE             PELOTAS
#
#   ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 0            RJ                 <NA>     2010-01-03        12:00:00
# 1            PA                 SBBE     2010-01-03        11:05:00
# 2            RJ                 SBRJ     2010-01-03        03:00:00
# 3            MT                 <NA>     2010-01-04        17:30:00
# 4            RS                 SBPK     2010-01-05        19:25:00
#
#    total_recomendacoes
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
# Substituindo todos os valores incorretos no dataframe por não informado

# %%
df.replace(['**','###!', '####', '****','*****','NULL'], pd.NA, inplace = True)
# Out:
# C:\Users\palmi\AppData\Roaming\Python\Python37\site-packages\pandas\core\missing.py:47: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask = arr == x
# C:\Users\palmi\AppData\Roaming\Python\Python37\site-packages\pandas\core\missing.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= arr == x

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BELÉM
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                    GRAVE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
# Contabilizar dados não informados

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2181
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2181
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %% [raw]
# Modificar NA para outro valor
# df.fillna(, inplace = True)

# %%
# a funçao df.dropna() apaga todas as linhas que tenham valores NA, deve-se tomar cuidado ao usa-la, como nao usamos o inplace = True a mudança é apenas na visualização
df.dropna()
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 1                  40349                INCIDENTE             BELÉM
# 2                  40351                INCIDENTE    RIO DE JANEIRO
# 4                  40324                INCIDENTE           PELOTAS
# 6                  40215                INCIDENTE             COARI
# 8                  39156          INCIDENTE GRAVE          CASCAVEL
# ...                  ...                      ...               ...
# 5743               79824                 ACIDENTE     RIO PARANAÍBA
# 5746               79769          INCIDENTE GRAVE     MANOEL URBANO
# 5747               79804                    GRAVE          CAMPINAS
# 5749               79802                INCIDENTE    RIO DE JANEIRO
# 5751               79844                INCIDENTE    RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 1               PA                 SBBE     2010-01-03        11:05:00
# ...

# %%
df
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao   ocorrencia_cidade  \
# 0                  40211                INCIDENTE      RIO DE JANEIRO
# 1                  40349                INCIDENTE               BELÉM
# 2                  40351                INCIDENTE      RIO DE JANEIRO
# 3                  39527                 ACIDENTE  LUCAS DO RIO VERDE
# 4                  40324                INCIDENTE             PELOTAS
# ...                  ...                      ...                 ...
# 5747               79804                    GRAVE            CAMPINAS
# 5748               79757          INCIDENTE GRAVE   LAGOA DA CONFUSÃO
# 5749               79802                INCIDENTE      RIO DE JANEIRO
# 5750               79756          INCIDENTE GRAVE           VICENTINA
# 5751               79844                INCIDENTE      RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# ...

# %%
# Podemos também deletar valores NA respectivos a uma única coluna

# %%
df.dropna(subset=['ocorrencia_aerodromo'])
# Out:
#       codigo_ocorrencia2 ocorrencia_classificacao ocorrencia_cidade  \
# 1                  40349                INCIDENTE             BELÉM
# 2                  40351                INCIDENTE    RIO DE JANEIRO
# 4                  40324                INCIDENTE           PELOTAS
# 6                  40215                INCIDENTE             COARI
# 8                  39156          INCIDENTE GRAVE          CASCAVEL
# ...                  ...                      ...               ...
# 5743               79824                 ACIDENTE     RIO PARANAÍBA
# 5746               79769          INCIDENTE GRAVE     MANOEL URBANO
# 5747               79804                    GRAVE          CAMPINAS
# 5749               79802                INCIDENTE    RIO DE JANEIRO
# 5751               79844                INCIDENTE    RIO DE JANEIRO
#
#      ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia ocorrencia_hora  \
# 1               PA                 SBBE     2010-01-03        11:05:00
# ...

# %%
# exclusão de valores duplicados
# df.drop_duplicates()

# %%
# TRANSFORMAÇÃO DOS DADOS

# %%
# Importar dados diretamente já corrigindo valores ausentes

# %%
valores_ausentes = ['**','***','###!', '####', '****','*****','NULL']
df2 = pd.read_csv("H://Meu_Github//Curso ETJ//ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst = True, na_values = valores_ausentes)
df2
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# Para que o schema funcione logo após a importação, o valor nullable = True deverá ser configurado para cada coluna com valor discordante NaN

# %%
schema = pa.DataFrameSchema(
columns = {
    "codigo_ocorrencia": pa.Column(pa.Int),
    "codigo_ocorrencia2": pa.Column(pa.Int),
    "ocorrencia_classificacao": pa.Column(pa.String),
    "ocorrencia_cidade": pa.Column(pa.String),
    "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2), nullable = True),
    "ocorrencia_aerodromo": pa.Column(pa.String, nullable = True),
    "ocorrencia_dia": pa.Column(pa.DateTime),
    "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable = True),
    "total_recomendacoes": pa.Column(pa.Int)
}
)

# %%
schema.validate(df2)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df2.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df2.loc[1]
#loc é usado para encontrar dados da linha utilizando o label como referencia
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df2.iloc[1]
#iloc é usado para encontrar dados da linha utilizando o indice como referencia
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
df2.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     349             try:
# --> 350                 return self._range.index(new_key)
#     351             except ValueError:
#
# ValueError: -1 is not in range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-92-0448a420b16a> in <module>
# ----> 1 df2.loc[-1]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ...

# %%
df2.iloc[-1]
# Out:
# codigo_ocorrencia                         79844
# codigo_ocorrencia2                        79844
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                RIO DE JANEIRO
# ocorrencia_uf                                RJ
# ocorrencia_aerodromo                       SBJR
# ocorrencia_dia              2020-12-31 00:00:00
# ocorrencia_hora                        13:24:00
# total_recomendacoes                           0
# Name: 5751, dtype: object

# %%
df2.loc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
# 15              39315               39315                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
# ...

# %%
df2.iloc[10:15]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 10              39789               39789                INCIDENTE
# 11              40069               40069                 ACIDENTE
# 12              40414               40414                INCIDENTE
# 13              39507               39507                 ACIDENTE
# 14              40107               40107                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 10    SÃO PEDRO DO SUL            RS                  NaN     2010-01-10
# 11           SÃO PAULO            SP                 SBMT     2010-01-10
# 12            BRASÍLIA            DF                 SBBR     2010-01-10
# 13  PRIMAVERA DO LESTE            MT                  NaN     2010-01-11
# 14              GURUPÁ            PA                 SNGU     2010-01-12
#
#    ocorrencia_hora  total_recomendacoes
# 10        21:30:00                    0
# 11        14:50:00                    8
# ...

# %%
df2.loc[:,'ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5747    SP
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    RJ
# Name: ocorrencia_uf, Length: 5752, dtype: object

# %%
df2['ocorrencia_uf']
# Out:
# 0       RJ
# 1       PA
# 2       RJ
# 3       MT
# 4       RS
#         ..
# 5747    SP
# 5748    TO
# 5749    RJ
# 5750    MS
# 5751    RJ
# Name: ocorrencia_uf, Length: 5752, dtype: object

# %%
df2.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# Localizando a linha onde o valor é nulo

# %%
df2.loc[df2.ocorrencia_uf.isnull()]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2227              49474               49474                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 2227  ÁGUAS INTERNACIONAIS           NaN                  NaN     2013-09-02
#
#      ocorrencia_hora  total_recomendacoes
# 2227        02:54:00                    0

# %%
filtro = df2.ocorrencia_aerodromo.isnull()
df2.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5741              79754               79754          INCIDENTE GRAVE
# 5744              79753               79753          INCIDENTE GRAVE
# 5745              79755               79755                 ACIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df2.count()
# Out:
# codigo_ocorrencia           5752
# codigo_ocorrencia2          5752
# ocorrencia_classificacao    5752
# ocorrencia_cidade           5752
# ocorrencia_uf               5751
# ocorrencia_aerodromo        3403
# ocorrencia_dia              5752
# ocorrencia_hora             5751
# total_recomendacoes         5752
# dtype: int64

# %%
# ocorrencias com mais de 10 recomendações

# %%
filtro = df2.total_recomendacoes > 10
df2.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 63                39992               39992                 ACIDENTE
# 326               42250               42250                 ACIDENTE
# 530               43471               43471                 ACIDENTE
# 727               44377               44377                 ACIDENTE
# 872               44796               44796                 ACIDENTE
# 884               44888               44888          INCIDENTE GRAVE
# 1062              45554               45554          INCIDENTE GRAVE
# 1972              47938               47938                INCIDENTE
# 2795              52265               52265                 ACIDENTE
# 3930              66432               66432          INCIDENTE GRAVE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 63               SÃO PAULO            SP                 SBMT     2010-02-17
# ...

# %%
# Mostrar apenas as colunas desejadas

# %%
filtro = df2.total_recomendacoes > 10
df2.loc[filtro, 'ocorrencia_cidade']
# Out:
# 63                 SÃO PAULO
# 326           RIO DE JANEIRO
# 530                SÃO PAULO
# 727                 ITÁPOLIS
# 872                   RECIFE
# 884     SÃO JOSÉ DOS PINHAIS
# 1062              UBERLÂNDIA
# 1972                BRASÍLIA
# 2795                  SANTOS
# 3930                 VITÓRIA
# Name: ocorrencia_cidade, dtype: object

# %%
filtro = df2.total_recomendacoes > 10
df2.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2795                SANTOS                   13
# 3930               VITÓRIA                   12

# %%
filtro = df2.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df2.loc[filtro, ['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#       ocorrencia_cidade  total_recomendacoes
# 7              CANUTAMA                    3
# 8              CASCAVEL                    2
# 9         PARÁ DE MINAS                    0
# 29             CURITIBA                    2
# 35               PALMAS                    0
# ...                 ...                  ...
# 5741       NOVA MARINGÁ                    0
# 5744           GOIATUBA                    0
# 5746      MANOEL URBANO                    0
# 5748  LAGOA DA CONFUSÃO                    0
# 5750          VICENTINA                    0
#
# [737 rows x 2 columns]

# %%
filtro1 = df2.ocorrencia_uf == 'SP'
filtro2 = df2.ocorrencia_classificacao == 'ACIDENTE'
df2.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069                 ACIDENTE
# 34                39322               39322                 ACIDENTE
# 37                39319               39319                 ACIDENTE
# 58                39275               39275                 ACIDENTE
# 61                41377               41377                 ACIDENTE
# ...                 ...                 ...                      ...
# 5619              79580               79580                 ACIDENTE
# 5631              79598               79598                 ACIDENTE
# 5648              79627               79627                 ACIDENTE
# 5673              79669               79669                 ACIDENTE
# 5696              79692               79692                 ACIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
filtro1 = df2.ocorrencia_uf == 'SP'
filtro2 = df2.ocorrencia_classificacao == 'ACIDENTE'
df2.loc[filtro1 & filtro2,['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#           ocorrencia_cidade  total_recomendacoes
# 11                SÃO PAULO                    8
# 34    SÃO BERNARDO DO CAMPO                    2
# 37                    IPERÓ                    3
# 58                SÃO PAULO                    3
# 61              SERRA NEGRA                    0
# ...                     ...                  ...
# 5619      BRAGANÇA PAULISTA                    0
# 5631                 ROSANA                    0
# 5648         BIRITIBA-MIRIM                    0
# 5673              SÃO PEDRO                    0
# 5696              CATANDUVA                    0
#
# [388 rows x 2 columns]

# %%
# ocorrencia cuja (classificação == INCIDENTE GRAVE ou classificação == ACIDENTE) e o estado == SP
filto1 = df2.ocorrencia_classificacao == 'INCIDENTE GRAVE' | df2.ocorrencia_classificacao == 'ACIDENTE'
filtro2 = df2.ocorrencia_uf == 'SP'
df2.loc[filtro1 & filtro2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops\roperator.py in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#      57
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     287             try:
# --> 288                 result = libops.scalar_binop(x, y, op)
# ...

# %%
# ocorrencia cuja (classificação == INCIDENTE GRAVE ou classificação == ACIDENTE) e o estado == SP
filto1 = (df2.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df2.ocorrencia_classificacao == 'ACIDENTE')
filtro2 = df2.ocorrencia_uf == 'SP'
df2.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrencia cuja (classificação == INCIDENTE GRAVE ou classificação == ACIDENTE) e o estado == SP
filto1 = df2.ocorrencia_classificacao.isin (['INCIDENTE GRAVE','ACIDENTE'])
filtro2 = df2.ocorrencia_uf == 'SP'
df2.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# 18                39828               39828                INCIDENTE
# 26                39847               39847                INCIDENTE
# 27                39768               39768                INCIDENTE
# ...                 ...                 ...                      ...
# 5704              79739               79739          INCIDENTE GRAVE
# 5705              79705               79705          INCIDENTE GRAVE
# 5715              79718               79718          INCIDENTE GRAVE
# 5742              79800               79800                INCIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrencias em cidades que comecem com a letra C

# %%
filtro1 = df2.ocorrencia_cidade.str[0] == 'C'
df2.loc[filtro1]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 6                 40215               40215                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 15                39315               39315                 ACIDENTE
# 20                40310               40310                INCIDENTE
# ...                 ...                 ...                      ...
# 5661              79649               79649                INCIDENTE
# 5663              79652               79652                INCIDENTE
# 5680              79683               79683                INCIDENTE
# 5696              79692               79692                 ACIDENTE
# 5747              79804               79804                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrencias em cidades que terminem com a letra A

# %%
filtro1 = df2.ocorrencia_cidade.str[-1] == 'A'
df2.loc[filtro1]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 12                40414               40414                INCIDENTE
# 15                39315               39315                 ACIDENTE
# 25                39772               39772                INCIDENTE
# 26                39847               39847                INCIDENTE
# ...                 ...                 ...                      ...
# 5738              79787               79787                INCIDENTE
# 5739              79749               79749                 ACIDENTE
# 5743              79824               79824                 ACIDENTE
# 5744              79753               79753          INCIDENTE GRAVE
# 5750              79756               79756          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrencias em cidades que terminem com a letra NA

# %%
filtro1 = df2.ocorrencia_cidade.str[-2:] == 'NA'
df2.loc[filtro1]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 51                39115               39115                 ACIDENTE
# 81                39914               39914                INCIDENTE
# 86                39993               39993          INCIDENTE GRAVE
# 138               40328               40328                 ACIDENTE
# 147               40321               40321                INCIDENTE
# ...                 ...                 ...                      ...
# 5624              79582               79582                INCIDENTE
# 5631              79598               79598                 ACIDENTE
# 5640              79620               79620                 ACIDENTE
# 5712              79725               79725                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# contains verifica se a string inteira possui alguma palavra com os caracteres NA
filtro1 = df2.ocorrencia_cidade.str.contains('NA')
df2.loc[filtro1]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 9                 39711               39711          INCIDENTE GRAVE
# 27                39768               39768                INCIDENTE
# 32                39318               39318                 ACIDENTE
# 34                39322               39322                 ACIDENTE
# 51                39115               39115                 ACIDENTE
# ...                 ...                 ...                      ...
# 5731              79746               79746                INCIDENTE
# 5737              79748               79748                 ACIDENTE
# 5743              79824               79824                 ACIDENTE
# 5747              79804               79804                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# contains verifica se a string inteira possui alguma palavra com os caracteres NA ou AL
filtro1 = df2.ocorrencia_cidade.str.contains('NA|AL')
df2.loc[filtro1]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 5                 39807               39807                INCIDENTE
# 9                 39711               39711          INCIDENTE GRAVE
# 17                39810               39810                INCIDENTE
# 27                39768               39768                INCIDENTE
# 32                39318               39318                 ACIDENTE
# ...                 ...                 ...                      ...
# 5737              79748               79748                 ACIDENTE
# 5738              79787               79787                INCIDENTE
# 5743              79824               79824                 ACIDENTE
# 5747              79804               79804                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrencias do ano 2015
filtro1 = df2.ocorrencia_dia.dt.year == 2015
df2.loc[filtro1]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 2996              52992               52992          INCIDENTE GRAVE
# 2997              52979               52979                 ACIDENTE
# 2998              53073               53073                INCIDENTE
# 2999              53074               53074                INCIDENTE
# 3000              52976               52976                 ACIDENTE
# ...                 ...                 ...                      ...
# 3462              60632               60632          INCIDENTE GRAVE
# 3463              60600               60600                INCIDENTE
# 3464              60642               60642                INCIDENTE
# 3465              60631               60631                 ACIDENTE
# 3466              60649               60649                 ACIDENTE
#
#          ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
# ocorrencias do ano 2015 e mes 12
filtro1 = df2.ocorrencia_dia.dt.year == 2015
filtro2 = df2.ocorrencia_dia.dt.month == 12
df2.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3428              53573               53573                INCIDENTE
# 3429              60601               60601                INCIDENTE
# 3430              53634               53634                INCIDENTE
# 3431              53636               53636                INCIDENTE
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
# 3440              53627               53627                INCIDENTE
# ...

# %%
# ocorrencias do ano 2015 e mes 12
filtro1 = (df2.ocorrencia_dia.dt.year == 2015) & (df2.ocorrencia_dia.dt.month == 12)
df2.loc[filtro1]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3428              53573               53573                INCIDENTE
# 3429              60601               60601                INCIDENTE
# 3430              53634               53634                INCIDENTE
# 3431              53636               53636                INCIDENTE
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
# 3440              53627               53627                INCIDENTE
# ...

# %%
# ocorrencias do ano 2015 e mes 12 e dia 8
filtro1 = df2.ocorrencia_dia.dt.year == 2015
filtro2 = df2.ocorrencia_dia.dt.month == 12
filtro3 = df2.ocorrencia_dia.dt.day == 8
df2.loc[filtro1 & filtro2 & filtro3]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3436             AGUAÍ            SP                  NaN     2015-12-08
# 3437             JALES            SP                 SDJL     2015-12-08
# 3438          CAMPINAS            SP                 SBKP     2015-12-08
# 3439     CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3436        14:30:00                    1
# 3437        10:20:00                    0
# 3438        16:19:00                    0
# 3439        13:00:00                    0

# %%
# ocorrencias do dia 03 ao dia 08 do mes 12 de 2015
filtro_ano = df2.ocorrencia_dia.dt.year == 2015
filtro_mes = df2.ocorrencia_dia.dt.month == 12
filtro_dia = (df2.ocorrencia_dia.dt.day >=3) & (df2.ocorrencia_dia.dt.day <=8)
df2.loc[filtro_ano & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3432  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3433         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
df2['ocorrencia_dia_hora'] = str(df2.ocorrencia_dia) + ' ' + df2.ocorrencia_hora

# %%
df2
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df2.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# ocorrencia_dia_hora                 object
# dtype: object

# %%
# Repare que data e hora foram transformados em string, para evitar esse tipo de problema deve-se converter para datetime 
# antes de atribuir a coluna nova ao dataframe

# %%
df2['ocorrencia_dia_hora'] = pd.to_datetime(df2.ocorrencia_dia.astype(str) + ' ' + df2.ocorrencia_hora)

# %% [markdown]
# ##

# %%
df2
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 4                 40324               40324                INCIDENTE
# ...                 ...                 ...                      ...
# 5747              79804               79804                INCIDENTE
# 5748              79757               79757          INCIDENTE GRAVE
# 5749              79802               79802                INCIDENTE
# 5750              79756               79756          INCIDENTE GRAVE
# 5751              79844               79844                INCIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# ...

# %%
df2.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# ocorrencia_dia_hora         datetime64[ns]
# dtype: object

# %%
# ocorrencias do dia 03 ao dia 08 do mes 12 de 2015
filtro_ano = df2.ocorrencia_dia_hora.dt.year == 2015
filtro_mes = df2.ocorrencia_dia_hora.dt.month == 12
filtro_dia = (df2.ocorrencia_dia_hora.dt.day >=3) & (df2.ocorrencia_dia_hora.dt.day <=8)
df2.loc[filtro_ano & filtro_mes & filtro_dia]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3432              53575               53575                INCIDENTE
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3436              53628               53628                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
# 3438              53631               53631                INCIDENTE
# 3439              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3432  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3433         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434               TRINDADE            GO                  NaN     2015-12-06
# ...

# %%
# Com as horas transfomadas para padrão tempo, podemos localizar eventos pelo horario

# %%
filtro = df2.ocorrencia_dia_hora >= '2015-12-03 11:00:00'
filtro1 = df2.ocorrencia_dia_hora <= '2015-12-08 11:00:00'
df2.loc[filtro & filtro1]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3433              60637               60637                INCIDENTE
# 3434              53625               53625                 ACIDENTE
# 3435              53626               53626                 ACIDENTE
# 3437              53629               53629                 ACIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3433    BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3434          TRINDADE            GO                  NaN     2015-12-06
# 3435         AMERICANA            SP                 SDAI     2015-12-06
# 3437             JALES            SP                 SDJL     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes ocorrencia_dia_hora
# 3433        16:47:00                    0 2015-12-03 16:47:00
# 3434        13:10:00                    3 2015-12-06 13:10:00
# 3435        15:00:00                    1 2015-12-06 15:00:00
# ...

# %%
# AGRUPAMENTO DE DADOS

# %%
# ocorrencias NO MES 03 DE 2015
filtro_ano = df2.ocorrencia_dia.dt.year == 2015
filtro_mes = df2.ocorrencia_dia.dt.month == 3
df3 = df2.loc[filtro_ano & filtro_mes]
df3
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3086              53183               53183                 ACIDENTE
# 3087              53120               53120                 ACIDENTE
# 3088              53109               53109                 ACIDENTE
# 3089              53112               53112                 ACIDENTE
# 3090              53152               53152          INCIDENTE GRAVE
# 3091              53167               53167                INCIDENTE
# 3092              53596               53596                INCIDENTE
# 3093              53149               53149                 ACIDENTE
# 3094              53148               53148                 ACIDENTE
# 3095              53153               53153                INCIDENTE
# 3096              53154               53154                INCIDENTE
# 3097              53238               53238                INCIDENTE
# 3098              53189               53189                INCIDENTE
# ...

# %%
df3.count()
# Out:
# codigo_ocorrencia           37
# codigo_ocorrencia2          37
# ocorrencia_classificacao    37
# ocorrencia_cidade           37
# ocorrencia_uf               37
# ocorrencia_aerodromo        21
# ocorrencia_dia              37
# ocorrencia_hora             37
# total_recomendacoes         37
# ocorrencia_dia_hora         37
# dtype: int64

# %%
df3.groupby(['ocorrencia_classificacao']).codigo_ocorrencia.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# Name: codigo_ocorrencia, dtype: int64

# %%
# quando contamos por colunas com dados nulos o resultado sai errado
df3.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            5
# INCIDENTE          14
# INCIDENTE GRAVE     2
# Name: ocorrencia_aerodromo, dtype: int64

# %%
# O size permite contar por numero de linhas e não pelos valores nulos corrigindo o problema acima
df3.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           15
# INCIDENTE          17
# INCIDENTE GRAVE     5
# dtype: int64

# %%
df3.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     5
# ACIDENTE           15
# INCIDENTE          17
# dtype: int64

# %%
df3.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          17
# ACIDENTE           15
# INCIDENTE GRAVE     5
# dtype: int64

# %%
# Obter dados da região sudeste durante o ano de 2010
filtro1 = df2.ocorrencia_dia.dt.year == 2010
filtro2 = df2.ocorrencia_uf.isin(['SP', 'MG', 'ES', 'RJ'])
dfsudeste2010 = df2.loc[filtro1 & filtro2]
dfsudeste2010
# Out:
#      codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                40211               40211                INCIDENTE
# 2                40351               40351                INCIDENTE
# 9                39711               39711          INCIDENTE GRAVE
# 11               40069               40069                 ACIDENTE
# 16               39809               39809                INCIDENTE
# ..                 ...                 ...                      ...
# 541              43722               43722                 ACIDENTE
# 544              43548               43548                INCIDENTE
# 548              43724               43724                 ACIDENTE
# 550              43730               43730                INCIDENTE
# 551              43975               43975                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# ...

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            40
# INCIDENTE          170
# INCIDENTE GRAVE     18
# dtype: int64

# %%
dfsudeste2010.count()
# Out:
# codigo_ocorrencia           228
# codigo_ocorrencia2          228
# ocorrencia_classificacao    228
# ocorrencia_cidade           228
# ocorrencia_uf               228
# ocorrencia_aerodromo        127
# ocorrencia_dia              228
# ocorrencia_hora             228
# total_recomendacoes         228
# ocorrencia_dia_hora         228
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_classificacao','ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  MG                7
#                           RJ                9
#                           SP               24
# INCIDENTE                 ES                5
#                           MG               39
#                           RJ               52
#                           SP               74
# INCIDENTE GRAVE           MG                5
#                           RJ                4
#                           SP                9
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_uf','ocorrencia_classificacao']).size()
# Out:
# ocorrencia_uf  ocorrencia_classificacao
# ES             INCIDENTE                    5
# MG             ACIDENTE                     7
#                INCIDENTE                   39
#                INCIDENTE GRAVE              5
# RJ             ACIDENTE                     9
#                INCIDENTE                   52
#                INCIDENTE GRAVE              4
# SP             ACIDENTE                    24
#                INCIDENTE                   74
#                INCIDENTE GRAVE              9
# dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO           47
# SÃO PAULO                33
# GUARULHOS                18
# BELO HORIZONTE           17
# CAMPINAS                 13
# MACAÉ                    12
# CONFINS                   7
# UBERLÂNDIA                5
# VITÓRIA                   4
# JUIZ DE FORA              4
# SÃO JOSÉ DO RIO PRETO     3
# SÃO JOSÉ DOS CAMPOS       3
# MARÍLIA                   3
# ARARAQUARA                2
# MONTES CLAROS             2
# CAMPOS DOS GOYTACAZES     2
# DIVINÓPOLIS               2
# IPATINGA                  2
# ITANHAÉM                  2
# JUNDIAÍ                   2
# POÇOS DE CALDAS           2
# RIBEIRÃO PRETO            2
# SOROCABA                  2
# UBERABA                   2
# BAURU                     2
# AREALVA                   2
# BOITUVA                   1
# BOCAINA                   1
# BOM JESUS DO AMPARO       1
# BOM JESUS DO GALHO        1
# BEBEDOURO                 1
# BRAGANÇA PAULISTA         1
# ...

# %%
filtro = dfsudeste2010.ocorrencia_cidade == 'RIO DE JANEIRO'
dfsudeste2010.loc[filtro].total_recomendacoes.sum()
# Out:
# 25

# %%
dfsudeste2010.groupby(['ocorrencia_aerodromo']).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAE     0
# SBAQ     0
# SBBH     0
# SBBP     9
# SBBU     0
# SBCF     0
# SBGL     3
# SBGR     0
# SBIP     0
# SBJD     7
# SBJR     3
# SBKP     0
# SBME     0
# SBMK     0
# SBML     0
# SBMT    27
# SBPC     0
# SBPR     1
# SBRJ    19
# SBRP     0
# SBSJ     0
# SBSP     0
# SBSR     0
# SBUL     0
# SBUR     0
# SBVT     0
# SDAM     0
# SDOI     1
# SDPW     0
# SDPY     0
# SNDT     0
# SNDV     0
# SNXT     0
# Name: total_recomendacoes, dtype: int64

# %%
dfsudeste2010.groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# AMERICANA                 0
# ARARAQUARA                0
# ARAÇATUBA                 0
# AREALVA                   0
# ARRAIAL DO CABO           0
# BAURU                     0
# BEBEDOURO                 0
# BELO HORIZONTE            2
# BOCAINA                   0
# BOITUVA                   1
# BOM JESUS DO AMPARO       0
# BOM JESUS DO GALHO        1
# BRAGANÇA PAULISTA         9
# BROTAS                    0
# CAJOBI                    0
# CAMANDUCAIA               9
# CAMPINAS                  0
# CAMPOS DOS GOYTACAZES     0
# CASIMIRO DE ABREU         0
# CONFINS                   0
# COROMANDEL                0
# COSMÓPOLIS                0
# DIAMANTINA                0
# DIVINÓPOLIS               0
# GUARULHOS                 0
# IPATINGA                  0
# IPERÓ                     3
# ITANHAÉM                  1
# ITÁPOLIS                  0
# JUIZ DE FORA              0
# JUNDIAÍ                   7
# LINHARES                  0
# ...

# %%
filtro = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade']).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade
# BELO HORIZONTE            2
# BOITUVA                   1
# BOM JESUS DO GALHO        1
# BRAGANÇA PAULISTA         9
# CAMANDUCAIA               9
# IPERÓ                     3
# ITANHAÉM                  1
# JUNDIAÍ                   7
# NOVO HORIZONTE            3
# RESENDE                   8
# RIO DE JANEIRO           25
# SÃO BERNARDO DO CAMPO     2
# SÃO PAULO                41
# TIMÓTEO                   3
# Name: total_recomendacoes, dtype: int64

# %%
filtro = dfsudeste2010.total_recomendacoes > 0
dfsudeste2010.loc[filtro].groupby(['ocorrencia_cidade', dfsudeste2010.ocorrencia_dia.dt.month]).total_recomendacoes.sum()
# Out:
# ocorrencia_cidade      ocorrencia_dia
# BELO HORIZONTE         2                  1
#                        3                  1
# BOITUVA                7                  1
# BOM JESUS DO GALHO     12                 1
# BRAGANÇA PAULISTA      11                 9
# CAMANDUCAIA            7                  9
# IPERÓ                  1                  3
# ITANHAÉM               9                  1
# JUNDIAÍ                5                  5
#                        6                  2
# NOVO HORIZONTE         7                  3
# RESENDE                4                  8
# RIO DE JANEIRO         4                  3
#                        7                  3
#                        8                 19
# SÃO BERNARDO DO CAMPO  1                  2
# SÃO PAULO              1                  8
#                        2                 14
#                        6                  2
#                        11                 6
# ...
